# %% [markdown]
# ### The Battle of the Neighborhoods

# %% [markdown]
# #### Introduction & Business Problem

# %% [markdown]
# #### Problem Background:

# %% [markdown]
# The City of New York, is the most populous city in the United States. It is the financial capital of USA and provides lot of business oppourtunities and business friendly environment. It is a global hub of business and commerce which means that the market is highly competitive. The high competitiveness leads to higher cost of doing business. Thus, any new business venture or expansion needs to be analysed carefully. The insights derived from analysis will give good understanding of the business environment which help in strategically targeting the market.

# %% [markdown]
# #### Problem Description:

# %% [markdown]
# A restaurant is a place where you can eat a meal and pay for it. In restaurants your food is usually served to you at your table by a waiter or waitress. The City of New York is famous for its excelllent cuisine. It's food culture includes an array of international cuisines influenced by the city's immigrant history.

# %% [markdown]
# So it is evident that to survive in such a competitive market, it is very important to startegically implement the entire business. One of the factors which plays a crucial plan in the restaurant business is the location. Considering New York as the city to start the business, few of the parameters to analysis are:

# %% [markdown]
# 1. New York Population
# 2. New York City Demographics
# 3. Nearby suppliers like Farmers Markets, Wholesale markets, etc
# 4. Nearby venues where moving population is high
# 5. Location Compititiveness
# 6. Targeted Audience

# %% [markdown]
# The objective is to analyse the locality and recommend which neighborhood of New York City will be best choice to start a restaurant.
